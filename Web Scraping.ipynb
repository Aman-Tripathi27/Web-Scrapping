# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers=headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
company = soup.find_all('div', class_="companyCardWrapper")

# %%
len(company)
# Out:
# 20

# %%
name = []
rating = []
reviews = []
cinfo = []
for i in company:
    
    name.append(i.find('h2').text.strip())
    rating.append(i.find('div', class_= "companyCardWrapper__companyRatingWrapper").text.strip())
    reviews.append(i.find('span', class_="companyCardWrapper__ActionCount").text.strip())
    cinfo.append(i.find('span', class_="companyCardWrapper__interLinking").text.strip())
    

d = {'name':name,
     'rating':rating,
     'reviews':reviews,
     'cinfo':cinfo}
    
df = pd.DataFrame(d)
df
# Out:
#                        name rating reviews  \
# 0                       TCS    3.8   66.9k
# 1                 Accenture    4.1   42.7k
# 2                 Cognizant    3.9   38.5k
# 3                     Wipro    3.8   35.5k
# 4                ICICI Bank    4.0     31k
# 5                 HDFC Bank    3.9   30.7k
# 6                   Infosys    3.9   29.2k
# 7                 Capgemini    3.8   27.1k
# 8             Tech Mahindra    3.7   25.4k
# 9                   HCLTech    3.7   24.9k
# 10                  Genpact    3.9   24.3k
# 11                Axis Bank    3.8   20.4k
# 12   Concentrix Corporation    3.9   20.1k
# 13                   Amazon    4.1   19.3k
# 14             Reliance Jio    3.9   18.6k
# 15                      IBM    4.1   18.6k
# 16  Larsen & Toubro Limited    4.0   17.4k
# 17          Reliance Retail    3.9   16.8k
# 18   HDB Financial Services    4.0   16.4k
# 19          Teleperformance    3.6   15.9k
#
#                                                 cinfo
# 0   IT Services & Consulting | 1 Lakh+ Employees |...
# 1   IT Services & Consulting | 1 Lakh+ Employees |...
# 2   IT Services & Consulting | 1 Lakh+ Employees |...
# 3   IT Services & Consulting | 1 Lakh+ Employees |...
# 4   Banking | 1 Lakh+ Employees | Public | 29 year...
# 5   Banking | 1 Lakh+ Employees | Public | 29 year...
# 6   IT Services & Consulting | 1 Lakh+ Employees |...
# 7   IT Services & Consulting | 1 Lakh+ Employees |...
# 8   IT Services & Consulting | 1 Lakh+ Employees |...
# 9   IT Services & Consulting | 1 Lakh+ Employees |...
# 10  IT Services & Consulting | 1 Lakh+ Employees |...
# 11  Banking | 50k-1 Lakh Employees | Public | 30 y...
# 12  BPO | 50k-1 Lakh Employees | Public | 40 years...
# 13  Internet | 1 Lakh+ Employees | Public | 29 yea...
# 14  Telecom | 50k-1 Lakh Employees | Public | 16 y...
# 15  Software Product | 50k-1 Lakh Employees | Publ...
# 16  Engineering & Construction | 10k-50k Employees...
# 17  Retail | 1 Lakh+ Employees | 17 years old | Na...
# 18  NBFC | 1 Lakh+ Employees | 16 years old | Ahme...
# 19  BPO | 50k-1 Lakh Employees | Forbes Global 200...

# %%
salaries
# Out:
# ['66.8k Reviews',
#  '42.6k Reviews',
#  '38.5k Reviews',
#  '35.5k Reviews',
#  '31k Reviews',
#  '30.7k Reviews',
#  '29.2k Reviews',
#  '27.1k Reviews',
#  '25.4k Reviews',
#  '24.9k Reviews',
#  '24.3k Reviews',
#  '20.4k Reviews',
#  '20.1k Reviews',
#  '19.3k Reviews',
#  '18.6k Reviews',
#  '18.6k Reviews',
#  '17.4k Reviews',
#  '16.8k Reviews',
#  '16.4k Reviews',
#  '15.8k Reviews']

# %%
final=pd.DataFrame()

for j in range(1,500):
    
    
    url="https://www.ambitionbox.com/list-of-companies?page={}".format(j)
    
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(url, headers=headers).text
    
    
    soup = BeautifulSoup(webpage, 'lxml')
    
    company = soup.find_all('div', class_="companyCardWrapper")
    
    name = []
    rating = []
    reviews = []
    cinfo = []
    
    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('div', class_= "companyCardWrapper__companyRatingWrapper").text.strip())
        reviews.append(i.find('span', class_="companyCardWrapper__ActionCount").text.strip())
        cinfo.append(i.find('span', class_="companyCardWrapper__interLinking").text.strip())
    

    d = {'name':name, 'rating':rating, 'reviews':reviews, 'cinfo':cinfo}
    df = pd.DataFrame(d)
    
    
    final = final.append(df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tk/60xlhr995g50_dnmjzx8j4j80000gn/T/ipykernel_1420/117368299.py in ?()
#      28     d = {'name':name, 'rating':rating, 'reviews':reviews, 'cinfo':cinfo}
#      29     df = pd.DataFrame(d)
#      30
#      31
# ---> 32     final = final.append(df,ignore_index=True)
#      33
#      34
#      35
#
# ~/Desktop/ml-course/sample-project/env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
